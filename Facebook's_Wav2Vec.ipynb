# %% [markdown]
# <a href="https://colab.research.google.com/github/Biswajitjuee/Speech-to-Text-Wav2vec2.0/blob/main/Facebook's_Wav2Vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers

# %%
import librosa

#Importin Pytorch
import torch

#Importing Wav2Vec
from transformers import Wav2Vec2ForCTC, Wav2Vec2Tokenizer

# %%
import IPython.display as display
display.Audio("/content/converted.wav", autoplay=True)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio, rate = librosa.load('/content/converted.wav', sr = 16000)

# %%
rate
# Out:
# 16000

# %%
tokenizer = Wav2Vec2Tokenizer.from_pretrained("facebook/wav2vec2-base-960h")
model = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-base-960h")

# %%
input_values = tokenizer(audio, return_tensors = "pt").input_values

# %%
logits = model(input_values).logits

# %%
prediction = torch.argmax(logits, dim = -1)

# %%
transcription = tokenizer.batch_decode(prediction)[0]

# %%
transcription
# Out:
# "HELP FROM GOD DO WE AGREE AND WE GOT IT BUT HERE WE ARE CELEBRATING TOGETHER ON THIS VERY JOYOUS OCCASION AND THERE IS NO PLACE IN THE WORLD I'D RATHER BE TO GIVE MY FIRST COMMENCEMENT ADDRESS"

# %% [markdown]
# **Link https://pub.towardsai.net/speech-to-text-with-wav2vec-2-0-b21c1e1ad701
